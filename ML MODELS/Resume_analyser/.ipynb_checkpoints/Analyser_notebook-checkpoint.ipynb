# %% [markdown]
# ## Imports

# %%
import os, math
import pandas as pd
import gensim
import numpy as np
import en_core_web_sm
nlp = en_core_web_sm.load()
from gensim.models import KeyedVectors
from os import path as ospath

# %% [markdown]
# ## Load google word2vec model

# %%
model = KeyedVectors.load_word2vec_format('word2vec_model.bin', binary=True, limit=200000)

# %% [markdown]
# ## skills and experience extracted as strings shall be used in the model

# %%
skills ="SKILLS TECHNICALSKILLS Proficient with Python • Java • C • c++ • Octave pandas numpy keras tensorflow • SQL • Matlab • Git • Linux(Ubuntu) • Latex Familiar with: MachineLearning • DeepLearning • NLP • Artiﬁcial Intelligence SOFTSKILLS Strong Leadership • Resourcefulness • PublicSpeaking • Hard-working"
exp = "WORK EXPERIENCE NIT ROURKELA INTERN (MAY 2019 - JUNE 2019) • Worked under the guidance of Prof. DrRatnakar Dash on the project ” Abnormal activity recognition using Neural Networks ” EXAM PREPARATION ONLINE INTERN (DECEMBER 2019 - FEBRUARY 2020) • Contributed towards building  recommendation system for the website TECHNICAL PROJECTS USER QUERY DETECTION FOR STACK OVERFLOW | IBM HACK FINALS 2019 • Github://user-query-identiﬁcation-StackOverﬂow DOCUMENT CLUSTERING | NLP • Document Clustering  based on Mueller’s Report using k-means approach  and other NLP techniques. • Github://Document-clustering ONLINE NEWS VIRALITY PREDICTION | DEEP LEARNING • Predicting Virality of content from New  and Informational websites • Github://OnlineNewsPopularity VOICE BASED GRIEVANCE REDRESSAL SYSTEM |SYND INNOVATE HACKATHON 2019 • Github://synd-inn ABNORMAL ACTIVITY RECOGNITION |COMPUTER VISION • Detection of Abnormal Activity in Surveillance Videos. • Github://anomaly-detection-using-ml MORTALITY AND LOS PREDICTION |OPTUM STRATETHON 2019 • Github://optum"

# %% [markdown]
# ## function to predict n most similar words using word2vec model

# %%
def most_similar(token, n):
    token = token.lower()
    tokens = [token]
    closest_values = [1]
    try:
        list_similar = model.most_similar(positive=[token],topn=n)
        
        for tupl in list_similar:
            tokens.append(tupl[0])
            closest_values.append(tupl[1])
    except:
        pass   
    return tokens, closest_values

# %% [markdown]
# ## read job description either from csv or as string

# %%
jd = pd.read_csv('jd.csv')
print(jd['description'])
# Out:
# 0    This is an opportunity to join a small but hig...
# Name: description, dtype: object

# %% [markdown]
# ## function for lemmatisation and cleaning of data

# %%
def lemm(word):
    try:
        symb = '''~'`!@#$%^&*)(_+-=}•{][|\:;",./<>?'''
        mod_token = ''
        
        for c in word:
            if (c not in symb):
                mod_token += c.lower()

        docx = nlp(mod_token)

        if (len(mod_token) == 0 or docx[0].is_stop):
            return None
        else:
            return docx[0].lemma_
    except:
        return None

# %% [markdown]
# ## lemmatize job description

# %%
for job_desc in jd['description']:
    resume_description = ''
    for w in job_desc.split():
        lemm_w = lemm(w)
        if (lemm_w is not None):
            resume_description += (lemm_w + ' ')
    print(resume_description)
    break
# Out:
# opportunity join small highly successful team diverse background finance economic mathematic computer science leverage advanced machine learn technology help lender use financial digital datum make credit decision look experience machine learn engineer join team drive stellar result require attribute 1 core interest passion technology quality take pride one work pride codebase motivate improve quality time drive learn technology bring new idea tech team 2 software engineering skilled software engineer able point project significant contribution want thing right way instead get thing clarity maintainability code important 3 python require excellent grasp language intimately familiar namespace datum structure iterator generator experience scientific numerical programming big plus 4 datum processing scale run highly complex computationally intensive process able build system handle process high reliability efficiency 5 technology good understanding machine learn library like sklearn kera tensorflow panda numpy matplotlib 6 infrastructure able handle automate deployment tool like container docker serverless api ex lambda function etc 7 understanding core ml concept heart machine learn company familiarity building model metric machine learn fundamental concept plus value cando attitude ability work independently desire learn combination gap experience training grow fast want grow ideal 1 experience scientific numerical programming big plus 2 machine learn experience big plus require 3 experience design system software architecture role description 1 build maintain datum pipeline link machine learn stack 2 add new feature vizualization core machine learn score product technical stack transparent great documentation demo training sessionstutorial articlesblog 3 leadership core project client engagement 4 perform project task independently require direct effort 1 rare opportunity work team consist india bright mind field include people study like nus stanford university carnegie mellon university iit kharagpur work like bank america world bank american express 2 significant operational autonomy uncharacteristic indian business environment 3 opportunity work realworld dataset pertain marquee bank financial institution country 4 exponential professional growth opportunity result significant financial upside form stockoption equity performance base bonus monsoon credittech focus machine learn artificial intelligence credit fin tech company office gurgaon small team 1150 employee

# %%
skills_lem = ""
exp_lem = ""

# %% [markdown]
# ## lemmatize skills

# %%
for w in skills.split():
    lemm_w = lemm(w)
    if (lemm_w is not None):
        skills_lem += (lemm_w + ' ')
print(skills_lem)
# Out:
# skill technicalskill proficient python java c c octave panda numpy kera tensorflow sql matlab git linuxubuntu latex familiar machinelearning deeplearne nlp artiﬁcial intelligence softskill strong leadership resourcefulness publicspeaking hardworke

# %% [markdown]
# ## lemmatize exp

# %%
for w in exp.split():
    lemm_w = lemm(w)
    if (lemm_w is not None):
        exp_lem += (lemm_w + ' ')
print(exp_lem)
# Out:
# work experience nit rourkela intern 2019 june 2019 work guidance prof drratnakar dash project " abnormal activity recognition neural network " exam preparation online intern december 2019 february 2020 contribute building recommendation system website technical project user query detection stack overflow ibm hack final 2019 githubuserqueryidentiﬁcationstackoverﬂow document clustering nlp document clustering base mueller report kmean approach nlp technique githubdocumentclustering online news virality prediction deep learn predict virality content new informational website githubonlinenewspopularity voice base grievance redressal system synd innovate hackathon 2019 githubsyndinn abnormal activity recognition computer vision detection abnormal activity surveillance video githubanomalydetectionusingml mortality los prediction optum stratethon 2019 githuboptum

# %% [markdown]
# ## get the closest words along with similarity score and store as key value pairs

# %%
word_val = {}
no_of_sim_w = 2
for w_r in resume_description.split():
    closest_words, sim = most_similar(w_r, no_of_sim_w)
    for i in range(len(closest_words)):
        word_val[closest_words[i]] = word_val.get(closest_words[i], 0)+sim[i]
        print(closest_words[i], word_val[closest_words[i]])
# Out:
# opportunity 1
# chance 0.7239693403244019
# opportunities 0.6625990867614746
# join 1
# joining 0.7053104639053345
# joined 0.6783664226531982
# small 1
# large 0.733115017414093
# tiny 0.718792736530304
# highly 1
# Highly 0.7600369453430176
# hugely 0.6424112319946289
# successful 1
# succesful 0.7813116312026978
# hugely_successful 0.6282203793525696
# team 1
# squad 0.6780169606208801
# teams 0.6687403917312622
# diverse 1
# culturally_diverse 0.715650737285614
# varied 0.6506704092025757
# background 1
# processed 0.6519132852554321
# scale 1
# large_scale 0.6019724607467651
# Scale 0.4772368371486664
# run 1
# runs 0.6569936275482178
# running 0.6062965393066406
# highly 2
# Highly 1.5200738906860352
# hugely 1.2848224639892578
# complex 1
# complicated 0.633661150932312
# Complex 0.5190267562866211
# computationally 1
# intensive 1
# Intensive 0.5753592252731323
# intense 0.5559916496276855
# process 1
# processes 0.6653715372085571
# procedure 0.5169258117675781
# able 2
# unable 1.3566317558288574
# trying 1.1337095499038696
# build 1
# construct 0.7394897937774658
# develop 0.6814135909080505
# system 1
# systems 0.7227916717529297
# System 0.5275423526763916
# handle 1
# handled 0.664297342300415
# handles 0.6541999578475952
# process 2
# processes 1.3307430744171143
# procedure 1.0338516235351562
# high 1
# low 0.7421891689300537
# High 0.5790752172470093
# reliability 2.5352970361709595
# dependability 0.6916364431381226
# Reliability 0.6655181646347046
# efficiency 1
# efficiencies 0.6739118099212646
# Efficiency 0.6548120379447937
# 5 1.9444672465324402
# 6 0.9529386758804321
# 4 3.824621021747589
# technology 4.574556827545166
# technologies 3.3329057693481445
# innovations 2.492316246032715
# good 1
# great 0.7291510105133057
# bad 0.7190051078796387
# understanding 1
# knowledge 0.6270675659179688
# understand 0.6188539266586304
# machine 3
# machines 2.3032461404800415
# machinery 1.5782516598701477
# learn 4
# teach 2.679414749145508
# Learn 2.611829996109009
# library 1
# libraries 0.7558815479278564
# Library 0.7552247643470764
# like 1
# really 0.5752447843551636
# weird 0.5676319599151611
# sklearn 1
# kera 1
# tensorflow 1
# panda 1
# giant_panda 0.825084388256073
# pandas 0.791919469833374
# numpy 1
# matplotlib 1
# 6 1.9529386758804321
# 5 2.8974059224128723
# 8 0.941486120223999
# infrastructure 1
# infrastructures 0.7863633632659912
# infrastructural 0.6708652377128601
# able 3
# unable 2.034947633743286
# trying 1.7005643248558044
# handle 2
# handled 1.32859468460083
# handles 1.3083999156951904
# automate 1
# automating 0.78577721118927
# automates 0.7620306015014648
# deployment 1
# deployments 0.7872536182403564
# deploying 0.7129220962524414
# tool 1
# tools 0.7423330545425415
# toolkit 0.6109014749526978
# like 2
# really 1.1504895687103271
# weird 1.1352639198303223
# container 1
# containers 0.8288033604621887
# shipping_container 0.6571112871170044
# docker 1
# serverless 1
# api 1
# ex 1
# Ex 0.7136280536651611
# former 0.703322172164917
# lambda 1
# function 1
# functions 0.7318060398101807
# functioning 0.603313684463501
# etc 1
# etc. 0.8108068108558655
# etc_etc 0.7153326272964478
# 7 1
# 8 1.8828150033950806
# 6 2.8894417881965637
# understanding 2
# knowledge 1.2541351318359375
# understand 1.2377078533172607
# core 2
# Core 1.091414213180542
# bedrock 0.9514907598495483
# ml 1
# mL 0.830415666103363
# ###ml 0.7467883229255676
# concept 1.674426794052124
# concepts 0.7372901439666748
# idea 1.674426794052124
# heart 1
# hearts 0.5908936262130737
# Heart 0.5589761734008789
# machine 4
# machines 3.0709948539733887
# machinery 2.1043355464935303
# learn 5
# teach 3.3492684364318848
# Learn 3.264787495136261
# company 1
# firm 0.6224362850189209
# companies 0.6134217977523804
# familiarity 1
# 3 7.521874666213989
# build 2
# construct 1.4789795875549316
# develop 1.362827181816101
# maintain 1
# maintaining 0.6800947785377502
# retain 0.6588594317436218
# datum 4
# pipeline 1
# pipelines 0.8258387446403503
# Pipeline 0.6627088785171509
# link 1
# links 0.7872259020805359
# linking 0.6370705962181091
# machine 7
# machines 5.37424099445343
# machinery 3.682587206363678
# learn 9
# teach 6.028683185577393
# Learn 5.87661749124527
# stack 1
# stacks 0.8278287649154663
# stacked 0.6564180850982666
# 2 7.67624032497406
# 3 8.47619879245758
# 4 6.639962017536163
# add 1
# Adding 0.5781972408294678
# Add 0.5681695342063904
# new 2
# revamped 1.1504039764404297
# newest 1.1344507932662964
# feature 1
# features 0.7477220296859741
# featured 0.6610954999923706
# vizualization 1
# core 3
# Core 1.637121319770813
# bedrock 1.4272361397743225
# machine 8
# machines 6.141989707946777
# machinery 4.2086710929870605
# learn 10
# teach 6.6985368728637695
# Learn 6.529574990272522
# score 1
# scoring 0.7196800708770752
# scores 0.6595723628997803
# product 1
# products 0.752609372138977
# Product 0.6524055600166321
# technical 1
# Technical 0.5986553430557251
# technological 0.4692639708518982
# stack 2
# stacks 1.6556575298309326
# stacked 1.3128361701965332
# transparent 1
# transparent_manner 0.6519731283187866
# transparency 1.205376923084259
# great 1.7291510105133057
# terrific 1.5399059653282166
# fantastic 0.7935211658477783
# documentation 1
# paperwork 0.6444611549377441
# documents 0.6371331810951233
# demo 1
# demos 0.8072099089622498
# Demo 0.5924333333969116
# training 2
# Training 1.3349419832229614
# trainings 1.320334553718567
# sessionstutorial 1
# articlesblog 1
# 3 9.47619879245758
# 2 8.630564332008362
# 4 7.584928572177887
# leadership 1
# leader 0.5659863948822021
# Leadership 0.5282222032546997
# core 4
# Core 2.182828426361084
# bedrock 1.9029815196990967
# project 2
# projects 1.504413366317749
# Project 1.2200560569763184
# client 1
# clients 0.7574333548545837
# Client 0.6169803738594055
# engagement 1
# Engagement 0.5665915012359619
# engagements 0.5575217008590698
# 4 8.584928572177887
# 3 10.42116528749466
# 5 3.8418731689453125
# perform 1
# performed 0.7695817947387695
# performing 0.7398282289505005
# project 3
# projects 2.2566200494766235
# Project 1.8300840854644775
# task 1
# daunting_task 0.7147124409675598
# monumental_task 0.7036417722702026
# independently 2
# separately 1.2372958660125732
# independent 1.1433348655700684
# require 4
# requires 3.072406530380249
# requiring 3.0000662803649902
# direct 1
# indirect 0.6217883825302124
# directly 0.5506802201271057
# effort 1
# efforts 0.756921112537384
# attempt 0.6435876488685608
# 1 4
# 2 9.55309510231018
# 3 11.310585260391235
# rare 1
# exceedingly_rare 0.6834594011306763
# rare_occurrence 0.6455217003822327
# opportunity 2
# chance 1.4479386806488037
# opportunities 1.3251981735229492
# work 3
# working 2.0462082624435425
# works 1.748407781124115
# team 4
# squad 2.7120678424835205
# teams 2.674961566925049
# consist 1
# consists 0.7992920279502869
# consisting 0.7753720283508301
# india 1
# indian 0.6967039704322815
# usa 0.6836210489273071
# bright 1
# brighter 0.6687309741973877
# dim 0.5912142992019653
# mind 1
# minds 0.6579318046569824
# thinking 0.4707818627357483
# Base 0.5299409627914429
# bonus 1
# bonuses 0.7357580661773682
# Bonus 0.6731491684913635
# monsoon 1
# monsoons 0.8474604487419128
# monsoon_rains 0.7573787569999695
# credittech 1
# focus 1
# focused 0.8213135004043579
# focusing 0.8119165897369385
# machine 9
# machines 6.9097384214401245
# machinery 4.734754979610443
# learn 11
# teach 7.3683905601501465
# Learn 7.182532489299774
# artificial 1
# Artificial 0.6219794154167175
# synthetic 0.4818407893180847
# intelligence 1
# Intelligence 0.7189884185791016
# intel 0.6356418132781982
# credit 2
# Credit 1.37821364402771
# loan 1.1119303703308105
# fin 1
# fins 0.6967175006866455
# dorsal_fin 0.617978572845459
# tech 2
# hi_tech 1.297379970550537
# technology 5.149113655090332
# company 2
# firm 1.2448725700378418
# companies 1.2268435955047607
# office 1
# offices 0.6557507514953613
# Office 0.5453395247459412
# gurgaon 1
# small 2
# large 1.466230034828186
# tiny 1.437585473060608
# team 5
# squad 3.3900848031044006
# teams 3.343701958656311
# 1150 1
# employee 1
# employees 0.718955397605896
# Employee 0.6880295276641846

# %% [markdown]
# ##  get counts

# %%
num_resumes = 1
count = {}
for w in word_val.keys():
    count[w] = 0
    try:
            if w in skills_lem.split() or w in exp_lem.split():
            #if w in skills.split() or w in exp.split():
                count[w] += 1
    except:
            pass

print(count)
# Out:
# {'opportunity': 0, 'chance': 0, 'opportunities': 0, 'join': 0, 'joining': 0, 'joined': 0, 'small': 0, 'large': 0, 'tiny': 0, 'highly': 0, 'Highly': 0, 'hugely': 0, 'successful': 0, 'succesful': 0, 'hugely_successful': 0, 'team': 0, 'squad': 0, 'teams': 0, 'diverse': 0, 'culturally_diverse': 0, 'varied': 0, 'background': 0, 'backgrounds': 0, 'Background': 0, 'finance': 0, 'Finance': 0, 'financing': 0, 'economic': 0, 'economy': 0, 'Economic': 0, 'mathematic': 0, 'computer': 1, 'computers': 0, 'laptop': 0, 'science': 0, 'sciences': 0, 'biology': 0, 'leverage': 0, 'leveraging': 0, 'leveraged': 0, 'advanced': 0, 'advancing': 0, 'advances': 0, 'machine': 0, 'machines': 0, 'machinery': 0, 'learn': 1, 'teach': 0, 'Learn': 0, 'technology': 0, 'technologies': 0, 'innovations': 0, 'help': 0, 'helping': 0, 'helps': 0, 'lender': 0, 'lenders': 0, 'mortgage_lender': 0, 'use': 0, 'using': 0, 'utilize': 0, 'financial': 0, 'Financial': 0, 'digital': 0, 'Digital': 0, 'digital_imaging': 0, 'datum': 0, 'make': 0, 'making': 0, 'made': 0, 'credit': 0, 'Credit': 0, 'loan': 0, 'decision': 0, 'decison': 0, 'decisions': 0, 'look': 0, 'looks': 0, 'looking': 0, 'experience': 1, 'experiences': 0, 'expertise': 0, 'engineer': 0, 'electrical_engineer': 0, 'mechanical_engineer': 0, 'drive': 0, 'drives': 0, 'driving': 0, 'stellar': 0, 'impressive': 0, 'solid': 0, 'result': 0, 'consequence': 0, 'resulting': 0, 'require': 0, 'requires': 0, 'requiring': 0, 'attribute': 0, 'attributed': 0, 'attributing': 0, '1': 0, '2': 0, '3': 0, 'core': 0, 'Core': 0, 'bedrock': 0, 'interest': 0, 'Interest': 0, 'interests': 0, 'passion': 0, 'passions': 0, 'enthusiasm': 0, 'quality': 0, 'Quality': 0, 'reliability': 0, 'take': 0, 'taking': 0, 'took': 0, 'pride': 0, 'joy': 0, 'prideful': 0, 'one': 0, 'only': 0, 'two': 0, 'work': 1, 'working': 0, 'works': 0, 'codebase': 0, 'motivate': 0, 'motivating': 0, 'inspire': 0, 'improve': 0, 'improving': 0, 'enhance': 0, 'time': 0, 'day': 0, 'moment': 0, 'bring': 0, 'bringing': 0, 'brought': 0, 'new': 1, 'revamped': 0, 'newest': 0, 'idea': 0, 'concept': 0, 'notion': 0, 'tech': 0, 'hi_tech': 0, '4': 0, 'software': 0, 'Software': 0, 'softwares': 0, 'engineering': 0, 'Engineering': 0, 'mechanical_engineering': 0, 'skilled': 0, 'highly_skilled': 0, 'Skilled': 0, 'able': 0, 'unable': 0, 'trying': 0, 'point': 0, 'points': 0, 'pointers': 0, 'project': 1, 'projects': 0, 'Project': 0, 'significant': 0, 'substantial': 0, 'signficant': 0, 'contribution': 0, 'contributions': 0, 'Contribution': 0, 'want': 0, 'do': 0, 'wanted': 0, 'thing': 0, 'things': 0, 'something': 0, 'right': 0, 'Right': 0, 'wrong': 0, 'way': 0, 'ways': 0, 'how': 0, 'instead': 0, 'rather': 0, 'Instead': 0, 'get': 0, 'getting': 0, 'got': 0, 'clarity': 0, 'coherence': 0, 'transparency': 0, 'maintainability': 0, 'maintainable': 0, 'code': 0, 'codes': 0, 'Code': 0, 'important': 0, 'vitally_important': 0, 'vital': 0, 'python': 1, 'pythons': 0, 'snake': 0, 'excellent': 0, 'terrific': 0, 'superb': 0, 'grasp': 0, 'grasped': 0, 'comprehend': 0, 'language': 0, 'Language': 0, 'languages': 0, 'intimately': 0, 'intricately': 0, 'inextricably': 0, 'familiar': 1, 'familar': 0, 'unfamiliar': 0, 'namespace': 0, 'schema': 0, 'filesystem': 0, 'structure': 0, 'structures': 0, 'organizational_structure': 0, 'iterator': 0, 'generator': 0, 'generators': 0, 'diesel_generator': 0, 'scientific': 0, 'peer_reviewed': 0, 'numerical': 0, 'numeric': 0, 'mathematical': 0, 'programming': 0, 'programing': 0, 'Programming': 0, 'big': 0, 'huge': 0, 'bigger': 0, 'plus': 0, 'minus': 0, '+': 0, '5': 0, 'processing': 0, 'Processing': 0, 'processed': 0, 'scale': 0, 'large_scale': 0, 'Scale': 0, 'run': 0, 'runs': 0, 'running': 0, 'complex': 0, 'complicated': 0, 'Complex': 0, 'computationally': 0, 'intensive': 0, 'Intensive': 0, 'intense': 0, 'process': 0, 'processes': 0, 'procedure': 0, 'build': 0, 'construct': 0, 'develop': 0, 'system': 1, 'systems': 0, 'System': 0, 'handle': 0, 'handled': 0, 'handles': 0, 'high': 0, 'low': 0,  ...

# %% [markdown]
# ## get resume score

# %%
score = {}
for i in range(num_resumes):
    score[i] = 0
    try:
        for w in word_val.keys():
            se = skills_lem.split().count(w) + exp_lem.split().count(w)
            score[i] += word_val[w]*se
    except:
        pass

# %% [markdown]
# ## print score

# %%
print(score[i])
# Out:
# 54.0
